# %%
#bai5
def bai5(A, k):
    for i in range(len(A)):
        if A[i]==k:
            return i+1
            print(i+1)
    return -1
A = list(map(int, input().split()))
k = int(input())
bai5(A, k)
# Out:
# -1

# %%
#bai6
def giaith(n):
    tich
    for i in range(1, n+1):
